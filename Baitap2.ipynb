# %%
from PIL import Image
from imgtools import *

# %%
my_dir = 'D:/'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (640, 400)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400>
# (640, 400)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x400>
# (32, 32)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=32x32>
# (48, 48)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=48x48>
# (64, 64)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=64x64>
# (640, 400)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x400>
